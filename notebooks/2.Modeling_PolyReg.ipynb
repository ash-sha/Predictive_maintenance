# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import plotly.graph_objects as go
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/data/processed/df_train.csv")
df_train
# Out:
#        engine  cycle  setting_1  setting_2  setting_3  \
# 0           1      1    34.9983     0.8400      100.0
# 1           1      2    41.9982     0.8408      100.0
# 2           1      3    24.9988     0.6218       60.0
# 3           1      4    42.0077     0.8416      100.0
# 4           1      5    25.0005     0.6203       60.0
# ...       ...    ...        ...        ...        ...
# 53754     260    312    20.0037     0.7000      100.0
# 53755     260    313    10.0022     0.2510      100.0
# 53756     260    314    25.0041     0.6200       60.0
# 53757     260    315    25.0033     0.6220       60.0
# 53758     260    316    35.0036     0.8400      100.0
#
#        (Fan inlet temperature) (◦R)  (LPC outlet temperature) (◦R)  \
# 0                            449.44                         555.32
# 1                            445.00                         549.90
# 2                            462.54                         537.31
# ...

# %%
df_test = pd.read_csv("/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/data/processed/df_test.csv")
df_test
# Out:
#        engine  cycle  setting_1  setting_2  setting_3  \
# 0           1      1     9.9987     0.2502      100.0
# 1           1      2    20.0026     0.7000      100.0
# 2           1      3    35.0045     0.8400      100.0
# 3           1      4    42.0066     0.8410      100.0
# 4           1      5    24.9985     0.6213       60.0
# ...       ...    ...        ...        ...        ...
# 33986     259    119    35.0015     0.8403      100.0
# 33987     259    120    42.0066     0.8405      100.0
# 33988     259    121    42.0061     0.8400      100.0
# 33989     259    122     0.0024     0.0003      100.0
# 33990     259    123    42.0033     0.8400      100.0
#
#        (Fan inlet temperature) (◦R)  (LPC outlet temperature) (◦R)  \
# 0                            489.05                         605.03
# 1                            491.19                         607.82
# 2                            449.44                         556.00
# ...

# %%
# Assume df_train and df_test are already loaded DataFrames with 'RUL' as the target variable
X_train = df_train.drop(columns=['RUL'])
y_train = df_train['RUL']
X_test = df_test.drop(columns=['RUL'])
y_test = df_test['RUL']

# %%
# Normalisation

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler on the training data_processing and transform both training and test data_processing
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %% [markdown]
# ### Model

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import RFE

# Polynomial Feature Transformation
degree = 2  # Degree of polynomial feature_engineering
poly = PolynomialFeatures(degree,include_bias=False)
X_train_poly = poly.fit_transform(X_train_normalized)
X_test_poly = poly.transform(X_test_normalized)

# Train the Model
model = LinearRegression(fit_intercept=True,n_jobs=-1)
rfe = RFE(model, n_features_to_select=10)
fit = rfe.fit(X_train_poly, y_train)

# Display selected feature_engineering
selected_features_rfe = poly.get_feature_names_out()[fit.support_]
print("Selected feature_engineering with RFE:", selected_features_rfe)
# Out:
# Selected features with RFE: ['x9' 'x23' 'x4 x9' 'x4 x20' 'x5^2' 'x5 x22' 'x9 x23' 'x20^2' 'x20 x23'
#  'x22^2']

# %%
# Transform training and test data_processing to keep only selected feature_engineering
X_train_rfe = rfe.transform(X_train_poly)
X_test_rfe = rfe.transform(X_test_poly)

# %%
# Train the model with selected feature_engineering
model.fit(X_train_rfe, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
import joblib

# Assuming `model` is your trained model
joblib.dump(model, '/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/models/polyreg.pkl')
# Out:
# ['/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/models/polyreg.pkl']

# %%
# Load the model
model = joblib.load('/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/models/polyreg.pkl')

# %%
# Make predictions
y_train_pred = model.predict(X_train_rfe)
y_test_pred = model.predict(X_test_rfe)

# %% [markdown]
# ### Evaluation

# %%
#MSE -train
def mse_tr(y_train, y_train_pred):
    mse = mean_squared_error(y_train, y_train_pred)
    return (f'Mean Squared Error - Train: {mse}')
mse_tr(y_train, y_train_pred)
# Out:
# 'Mean Squared Error - Train: 4563.220530234255'

# %%
# R-squared evaluation - train
def r2_tr(y_train, y_train_pred):
    r_squared = r2_score(y_train, y_train_pred)
    return (f'R-squared - Train: {r_squared}')
r2_tr(y_train, y_train_pred)
# Out:
# 'R-squared - Train: 0.04652067119435166'

# %%
#MSE -test
def mse_tt(y_test, y_test_pred):
    mse = mean_squared_error(y_test, y_test_pred)
    return (f'Mean Squared Error - Test: {mse}')
mse_tt(y_test, y_test_pred)
# Out:
# 'Mean Squared Error - Test: 4586.996644166812'

# %%
# R-squared evaluation - test
def r2_tt(y_test, y_test_pred):
    r_squared = r2_score(y_test, y_test_pred)
    return (f'R-squared - Test: {r_squared}')
r2_tt(y_test, y_test_pred)
# Out:
# 'R-squared - Test: -0.9017035126468613'

# %%
### Polynomial regression with MinMAx scaled and RFE method
