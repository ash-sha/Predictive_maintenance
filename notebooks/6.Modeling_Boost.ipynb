# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
import xgboost as xgb
import optuna
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv("/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/data/processed/df_train_processed.csv")
df_train
# Out:
#        cycle      s2       s3       s4      s7       s8    s11     s12  \
# 0          1  641.82  1589.70  1400.60  554.36  2388.06  47.47  521.66
# 1          2  642.15  1591.82  1403.14  553.75  2388.04  47.49  522.28
# 2          3  642.35  1587.99  1404.20  554.26  2388.08  47.27  522.42
# 3          4  642.35  1582.79  1401.87  554.45  2388.11  47.13  522.86
# 4          5  642.37  1582.85  1406.22  554.00  2388.06  47.28  522.19
# ...      ...     ...      ...      ...     ...      ...    ...     ...
# 20626    196  643.49  1597.98  1428.63  551.43  2388.19  48.07  519.49
# 20627    197  643.54  1604.50  1433.58  550.86  2388.23  48.04  519.68
# 20628    198  643.42  1602.46  1428.18  550.94  2388.24  48.09  520.01
# 20629    199  643.23  1605.26  1426.53  550.68  2388.25  48.39  519.67
# 20630    200  643.85  1600.38  1432.14  550.79  2388.26  48.20  519.30
#
#            s13      s14     s15  s17    s20      s21  RUL
# 0      2388.02  8138.62  8.4195  392  39.06  23.4190  191
# 1      2388.07  8131.49  8.4318  392  39.00  23.4236  190
# 2      2388.03  8133.23  8.4178  390  38.95  23.3442  189
# 3      2388.08  8133.83  8.3682  392  38.88  23.3739  188
# 4      2388.04  8133.80  8.4294  393  38.90  23.4044  187
# ...        ...      ...     ...  ...    ...      ...  ...
# 20626  2388.26  8137.60  8.4956  397  38.49  22.9735    4
# 20627  2388.22  8136.50  8.5139  395  38.30  23.1594    3
# 20628  2388.24  8141.05  8.5646  398  38.44  22.9333    2
# 20629  2388.23  8139.29  8.5389  395  38.29  23.0640    1
# 20630  2388.26  8137.33  8.5036  396  38.37  23.0522    0
#
# [20631 rows x 15 columns]

# %%
df_test = pd.read_csv("/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/data/processed/df_test_processed.csv")
df_test
# Out:
#        cycle      s2       s3       s4      s7       s8    s11     s12  \
# 0          1  643.02  1585.29  1398.21  553.90  2388.04  47.20  521.72
# 1          2  641.71  1588.45  1395.42  554.85  2388.01  47.50  522.16
# 2          3  642.46  1586.94  1401.34  554.11  2388.05  47.50  521.97
# 3          4  642.44  1584.12  1406.42  554.07  2388.03  47.28  521.38
# 4          5  642.51  1587.19  1401.92  554.16  2388.01  47.31  522.15
# ...      ...     ...      ...      ...     ...      ...    ...     ...
# 13091    194  643.24  1599.45  1415.79  553.41  2388.02  47.69  520.69
# 13092    195  643.22  1595.69  1422.05  553.22  2388.05  47.60  521.05
# 13093    196  643.44  1593.15  1406.82  553.04  2388.11  47.57  521.18
# 13094    197  643.26  1594.99  1419.36  553.37  2388.07  47.61  521.33
# 13095    198  642.95  1601.62  1424.99  552.48  2388.06  47.80  521.07
#
#            s13      s14     s15  s17    s20      s21  RUL
# 0      2388.03  8125.55  8.4052  392  38.86  23.3735  112
# 1      2388.06  8139.62  8.3803  393  39.02  23.3916  112
# 2      2388.03  8130.10  8.4441  393  39.08  23.4166  112
# 3      2388.05  8132.90  8.3917  391  39.00  23.3737  112
# 4      2388.03  8129.54  8.4031  390  38.99  23.4130  112
# ...        ...      ...     ...  ...    ...      ...  ...
# 13091  2388.00  8213.28  8.4715  394  38.65  23.1974   20
# 13092  2388.09  8210.85  8.4512  395  38.57  23.2771   20
# 13093  2388.04  8217.24  8.4569  395  38.62  23.2051   20
# 13094  2388.08  8220.48  8.4711  395  38.66  23.2699   20
# 13095  2388.05  8214.64  8.4903  396  38.70  23.1855   20
#
# [13096 rows x 15 columns]

# %%
# Assume df_train and df_test are already loaded DataFrames with 'RUL' as the target variable

X_train = df_train.drop(columns=['RUL'])
y_train = df_train[['RUL']]
X_test = df_test.drop(columns=['RUL'])
y_test = df_test[['RUL']]

# %%
# Normalisation
scaler = MinMaxScaler()

# Fit the scaler on the training data_processing and transform both training and test data_processing
X_train_normalized = scaler.fit_transform(X_train)
X_test_normalized = scaler.transform(X_test)

# %%
# log transform stabilises variance and makes distribution more comparable
# Transform target variable
y_train_normalized = np.log(y_train + 1)
y_test_normalized = np.log(y_test + 1)

# %%
X_train_part, X_valid, y_train_part, y_valid = train_test_split(X_train_normalized, y_train_normalized, test_size=0.2, random_state=42)

# %% [markdown]
# ### Model

# %%
# Define the objective function for Optuna
def objective(trial):
    # Suggest hyperparameters
    params = {
        'objective': 'reg:squarederror',
        'booster': trial.suggest_categorical('booster', ['gbtree']),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0)
    }

    # Initialize RandomForest with suggested hyperparameters
    model = xgb.XGBRegressor(**params, random_state=42,n_jobs=-1)

    # 5-fold cross-validation on the train set
    cv_scores = cross_val_score(model, X_train_part, y_train_part, cv=5, scoring='r2')
    
    return cv_scores.mean()

# Create study and optimize
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=60)

# Get the best hyperparameters
print(f'Best hyperparameters: {study.best_params}')
# Out:
# [I 2024-09-09 11:02:04,545] A new study created in memory with name: no-name-946cd7b1-0331-4484-a8ac-5c75601ec66b
# [I 2024-09-09 11:02:05,554] Trial 0 finished with value: 0.13637547492980956 and parameters: {'booster': 'gbtree', 'n_estimators': 71, 'learning_rate': 0.0013498352745368333, 'max_depth': 6, 'subsample': 0.6340342820906038, 'colsample_bytree': 0.5484668498245414, 'lambda': 1.6583282516784708, 'alpha': 1.848538683530365}. Best is trial 0 with value: 0.13637547492980956.
# [I 2024-09-09 11:02:08,778] Trial 1 finished with value: 0.8869575023651123 and parameters: {'booster': 'gbtree', 'n_estimators': 397, 'learning_rate': 0.016335498113328607, 'max_depth': 4, 'subsample': 0.5914970941665822, 'colsample_bytree': 0.965546106257042, 'lambda': 0.005934838170497568, 'alpha': 0.03467527631509674}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:02:40,641] Trial 2 finished with value: 0.8787145376205444 and parameters: {'booster': 'gbtree', 'n_estimators': 492, 'learning_rate': 0.05568004851610737, 'max_depth': 15, 'subsample': 0.8576805826728426, 'colsample_bytree': 0.8826895442131129, 'lambda': 1.478337393091294, 'alpha': 0.001962570402589063}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:02:50,993] Trial 3 finished with value: 0.8798806190490722 and parameters: {'booster': 'gbtree', 'n_estimators': 177, 'learning_rate': 0.052180039994022195, 'max_depth': 14, 'subsample': 0.8094196670983309, 'colsample_bytree': 0.8905759251112277, 'lambda': 2.6429437387526082, 'alpha': 0.33009419888261765}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:27,645] Trial 4 finished with value: 0.6377698898315429 and parameters: {'booster': 'gbtree', 'n_estimators': 470, 'learning_rate': 0.0014756213331676555, 'max_depth': 15, 'subsample': 0.7780029732242966, 'colsample_bytree': 0.8690149128401318, 'lambda': 0.32779161297412324, 'alpha': 0.1009786788555971}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:28,392] Trial 5 finished with value: 0.8797545671463013 and parameters: {'booster': 'gbtree', 'n_estimators': 58, 'learning_rate': 0.07762795176558275, 'max_depth': 6, 'subsample': 0.7548910828260031, 'colsample_bytree': 0.5028092475487314, 'lambda': 0.011153331520930355, 'alpha': 8.939467675961712}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:30,975] Trial 6 finished with value: 0.8341157674789429 and parameters: {'booster': 'gbtree', 'n_estimators': 412, 'learning_rate': 0.004691814727430879, 'max_depth': 3, 'subsample': 0.9745889904173699, 'colsample_bytree': 0.9798597971477084, 'lambda': 0.6250673334904134, 'alpha': 0.009303275654527288}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:44,740] Trial 7 finished with value: 0.8787671566009522 and parameters: {'booster': 'gbtree', 'n_estimators': 445, 'learning_rate': 0.07785152492077634, 'max_depth': 11, 'subsample': 0.9973082018939234, 'colsample_bytree': 0.7426935171755025, 'lambda': 0.5266196125652017, 'alpha': 0.10397656459199549}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:46,786] Trial 8 finished with value: 0.45863072872161864 and parameters: {'booster': 'gbtree', 'n_estimators': 339, 'learning_rate': 0.0013224542668059613, 'max_depth': 3, 'subsample': 0.825219686037136, 'colsample_bytree': 0.5868152271153, 'lambda': 1.932326011425831, 'alpha': 0.0011662648350311048}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:03:51,214] Trial 9 finished with value: 0.5248006582260132 and parameters: {'booster': 'gbtree', 'n_estimators': 271, 'learning_rate': 0.0018016489315731375, 'max_depth': 7, 'subsample': 0.6688970220032885, 'colsample_bytree': 0.7326995032781605, 'lambda': 0.5164003042896554, 'alpha': 0.02525102286948712}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:04:01,627] Trial 10 finished with value: 0.8866290092468262 and parameters: {'booster': 'gbtree', 'n_estimators': 340, 'learning_rate': 0.018465227481397766, 'max_depth': 10, 'subsample': 0.5031923259004947, 'colsample_bytree': 0.9871421919019507, 'lambda': 0.0011756890424439244, 'alpha': 0.01253122727002358}. Best is trial 1 with value: 0.8869575023651123.
# [I 2024-09-09 11:04:12,532] Trial 11 finished with value: 0.8871155977249146 and parameters: {'booster': 'gbtree', 'n_estimators': 335, 'learning_rate': 0.012579747469712582, 'max_depth': 10, 'subsample': 0.5078371836017718, 'colsample_bytree': 0.9831367794873779, 'lambda': 0.0010128271040222372, 'alpha': 0.01146332185577077}. Best is trial 11 with value: 0.8871155977249146.
# [I 2024-09-09 11:04:27,878] Trial 12 finished with value: 0.8863420963287354 and parameters: {'booster': 'gbtree', 'n_estimators': 350, 'learning_rate': 0.016420306697704803, 'max_depth': 12, 'subsample': 0.504104065148516, 'colsample_bytree': 0.8306855416768946, 'lambda': 0.0012219806537801495, 'alpha': 0.02868863099441053}. Best is trial 11 with value: 0.8871155977249146.
# [I 2024-09-09 11:04:34,341] Trial 13 finished with value: 0.856437623500824 and parameters: {'booster': 'gbtree', 'n_estimators': 256, 'learning_rate': 0.0068869520292077595, 'max_depth': 8, 'subsample': 0.5976422649583298, 'colsample_bytree': 0.9464046198145328, 'lambda': 0.009025896119917465, 'alpha': 0.004095384871951412}. Best is trial 11 with value: 0.8871155977249146.
# [I 2024-09-09 11:04:44,705] Trial 14 finished with value: 0.8873255848884583 and parameters: {'booster': 'gbtree', 'n_estimators': 397, 'learning_rate': 0.021100850190203507, 'max_depth': 9, 'subsample': 0.5729889770282528, 'colsample_bytree': 0.6662548524604406, 'lambda': 0.007769941474997061, 'alpha': 0.3997438347299487}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:04:50,180] Trial 15 finished with value: 0.8863360047340393 and parameters: {'booster': 'gbtree', 'n_estimators': 216, 'learning_rate': 0.02755855329592815, 'max_depth': 9, 'subsample': 0.6893581203620653, 'colsample_bytree': 0.6580961305506403, 'lambda': 0.04503861789189176, 'alpha': 0.41020913459524927}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:03,759] Trial 16 finished with value: 0.798835277557373 and parameters: {'booster': 'gbtree', 'n_estimators': 362, 'learning_rate': 0.0036038928536562993, 'max_depth': 12, 'subsample': 0.5398441619651273, 'colsample_bytree': 0.6606436432187134, 'lambda': 0.0032229171452788493, 'alpha': 0.4601267201099412}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:10,752] Trial 17 finished with value: 0.8817484378814697 and parameters: {'booster': 'gbtree', 'n_estimators': 301, 'learning_rate': 0.010659110760403408, 'max_depth': 9, 'subsample': 0.5678746735069357, 'colsample_bytree': 0.8117805576696574, 'lambda': 0.04058547216537841, 'alpha': 1.3880807234466657}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:18,990] Trial 18 finished with value: 0.8825757265090942 and parameters: {'booster': 'gbtree', 'n_estimators': 157, 'learning_rate': 0.034782150294544616, 'max_depth': 13, 'subsample': 0.6942340657579198, 'colsample_bytree': 0.649594138677391, 'lambda': 0.024875347338353695, 'alpha': 0.1713062574913224}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:29,880] Trial 19 finished with value: 0.8837672472000122 and parameters: {'booster': 'gbtree', 'n_estimators': 407, 'learning_rate': 0.009782358674221168, 'max_depth': 10, 'subsample': 0.9095089545984145, 'colsample_bytree': 0.7084410610034165, 'lambda': 0.0030730938777364315, 'alpha': 1.4344242033138657}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:34,245] Trial 20 finished with value: 0.6814998745918274 and parameters: {'booster': 'gbtree', 'n_estimators': 304, 'learning_rate': 0.0028649120008674644, 'max_depth': 7, 'subsample': 0.5525013480930211, 'colsample_bytree': 0.7861760730404171, 'lambda': 0.09161466294337443, 'alpha': 8.93061422839436}. Best is trial 14 with value: 0.8873255848884583.
# [I 2024-09-09 11:05:38,314] Trial 21 finished with value: 0.888419258594513 and parameters: {'booster': 'gbtree', 'n_estimators': 400, 'learning_rate': 0.016869496640237437, 'max_depth': 5, 'subsample': 0.608603429472322, 'colsample_bytree': 0.9322140707562224, 'lambda': 0.004109740545199049, 'alpha': 0.02095694405755538}. Best is trial 21 with value: 0.888419258594513.
# [I 2024-09-09 11:05:42,662] Trial 22 finished with value: 0.8889745950698853 and parameters: {'booster': 'gbtree', 'n_estimators': 448, 'learning_rate': 0.028872729675313655, 'max_depth': 5, 'subsample': 0.6347759348933066, 'colsample_bytree': 0.919915947609121, 'lambda': 0.0027611107083262104, 'alpha': 0.006379760124860734}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:05:47,232] Trial 23 finished with value: 0.8886627316474914 and parameters: {'booster': 'gbtree', 'n_estimators': 445, 'learning_rate': 0.030482976069411985, 'max_depth': 5, 'subsample': 0.6368164266941045, 'colsample_bytree': 0.9014578189765952, 'lambda': 0.003706341447954011, 'alpha': 0.005085703601465073}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:05:51,493] Trial 24 finished with value: 0.8881345510482788 and parameters: {'booster': 'gbtree', 'n_estimators': 441, 'learning_rate': 0.03606396191174155, 'max_depth': 5, 'subsample': 0.6366787064726785, 'colsample_bytree': 0.9215594500316227, 'lambda': 0.003347336794599666, 'alpha': 0.003091433083397969}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:05:56,367] Trial 25 finished with value: 0.8884426116943359 and parameters: {'booster': 'gbtree', 'n_estimators': 500, 'learning_rate': 0.027306407830925472, 'max_depth': 5, 'subsample': 0.7249555985307822, 'colsample_bytree': 0.9222769330126427, 'lambda': 6.532923003568032, 'alpha': 0.006178886499545056}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:06:00,214] Trial 26 finished with value: 0.8881472706794739 and parameters: {'booster': 'gbtree', 'n_estimators': 492, 'learning_rate': 0.04791524249801576, 'max_depth': 4, 'subsample': 0.7129099640742307, 'colsample_bytree': 0.8348814457747986, 'lambda': 6.545854698683983, 'alpha': 0.006691586003761347}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:06:04,839] Trial 27 finished with value: 0.8881051182746887 and parameters: {'booster': 'gbtree', 'n_estimators': 454, 'learning_rate': 0.033792845353959884, 'max_depth': 5, 'subsample': 0.7302143144013431, 'colsample_bytree': 0.9056495780582491, 'lambda': 9.211922034176174, 'alpha': 0.0010160658727209311}. Best is trial 22 with value: 0.8889745950698853.
# [I 2024-09-09 11:06:11,097] Trial 28 finished with value: 0.8889797568321228 and parameters: {'booster': 'gbtree', 'n_estimators': 491, 'learning_rate': 0.02469438411662706, 'max_depth': 6, 'subsample': 0.67111684876543, 'colsample_bytree': 0.8542702307126664, 'lambda': 0.12031406164706021, 'alpha': 0.053802550738739546}. Best is trial 28 with value: 0.8889797568321228.
# [I 2024-09-09 11:06:13,000] Trial 29 finished with value: 0.6913984060287476 and parameters: {'booster': 'gbtree', 'n_estimators': 118, 'learning_rate': 0.006836119018768715, 'max_depth': 7, 'subsample': 0.648493161611806, 'colsample_bytree': 0.8622607535569042, 'lambda': 0.1495831528081801, 'alpha': 0.055799318512691674}. Best is trial 28 with value: 0.8889797568321228.
# [I 2024-09-09 11:06:18,474] Trial 30 finished with value: 0.8890010595321656 and parameters: {'booster': 'gbtree', 'n_estimators': 434, 'learning_rate': 0.025746243225565683, 'max_depth': 6, 'subsample': 0.6281082294460331, 'colsample_bytree': 0.7984246325139851, 'lambda': 0.018264251053647786, 'alpha': 0.0039607126657931185}. Best is trial 30 with value: 0.8890010595321656.
# [I 2024-09-09 11:06:23,824] Trial 31 finished with value: 0.8887288093566894 and parameters: {'booster': 'gbtree', 'n_estimators': 433, 'learning_rate': 0.026131146840410475, 'max_depth': 6, 'subsample': 0.6339334758765027, 'colsample_bytree': 0.7875768122229871, 'lambda': 0.02216936727700512, 'alpha': 0.002940314493493497}. Best is trial 30 with value: 0.8890010595321656.
# [I 2024-09-09 11:06:28,922] Trial 32 finished with value: 0.8890104413032531 and parameters: {'booster': 'gbtree', 'n_estimators': 421, 'learning_rate': 0.024701463479854264, 'max_depth': 6, 'subsample': 0.6691287820708951, 'colsample_bytree': 0.7791326216244641, 'lambda': 0.018850906758780657, 'alpha': 0.0024654606416441567}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:06:33,769] Trial 33 finished with value: 0.8881437659263611 and parameters: {'booster': 'gbtree', 'n_estimators': 381, 'learning_rate': 0.04668998011261891, 'max_depth': 6, 'subsample': 0.6709794504841834, 'colsample_bytree': 0.7737506987348634, 'lambda': 0.09392138343065372, 'alpha': 0.0023780940521428103}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:06:37,617] Trial 34 finished with value: 0.8869725823402405 and parameters: {'booster': 'gbtree', 'n_estimators': 473, 'learning_rate': 0.013139486552386536, 'max_depth': 4, 'subsample': 0.5998075337382619, 'colsample_bytree': 0.8459302011273189, 'lambda': 0.01704719239023, 'alpha': 0.0017685374232266843}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:06:47,047] Trial 35 finished with value: 0.8826716661453247 and parameters: {'booster': 'gbtree', 'n_estimators': 473, 'learning_rate': 0.06453128248392859, 'max_depth': 8, 'subsample': 0.7682423415643866, 'colsample_bytree': 0.8092610006488985, 'lambda': 0.1923340423653531, 'alpha': 0.048709502078879655}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:06:55,548] Trial 36 finished with value: 0.8880787491798401 and parameters: {'booster': 'gbtree', 'n_estimators': 427, 'learning_rate': 0.021358731639507873, 'max_depth': 8, 'subsample': 0.6672793250994753, 'colsample_bytree': 0.6960215828499863, 'lambda': 0.04980415178577657, 'alpha': 0.0016481661968396194}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:01,673] Trial 37 finished with value: 0.88661208152771 and parameters: {'booster': 'gbtree', 'n_estimators': 375, 'learning_rate': 0.041473013142392316, 'max_depth': 7, 'subsample': 0.6169858873150453, 'colsample_bytree': 0.8755690239992469, 'lambda': 0.014591334923770164, 'alpha': 0.01847964459689621}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:04,547] Trial 38 finished with value: 0.8872181415557862 and parameters: {'booster': 'gbtree', 'n_estimators': 465, 'learning_rate': 0.062125408288579334, 'max_depth': 3, 'subsample': 0.7916096077425877, 'colsample_bytree': 0.766586897362666, 'lambda': 0.002081044853118927, 'alpha': 0.008919276568516526}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:08,622] Trial 39 finished with value: 0.8855256199836731 and parameters: {'booster': 'gbtree', 'n_estimators': 484, 'learning_rate': 0.09033223453866286, 'max_depth': 4, 'subsample': 0.6997508134332645, 'colsample_bytree': 0.9540280425021546, 'lambda': 0.028109890780732887, 'alpha': 0.05150685567322322}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:14,140] Trial 40 finished with value: 0.8887440085411071 and parameters: {'booster': 'gbtree', 'n_estimators': 421, 'learning_rate': 0.022862837615946256, 'max_depth': 6, 'subsample': 0.7474570165091627, 'colsample_bytree': 0.8081245802832641, 'lambda': 0.006145010277491027, 'alpha': 0.0035254418216536854}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:19,456] Trial 41 finished with value: 0.888259482383728 and parameters: {'booster': 'gbtree', 'n_estimators': 419, 'learning_rate': 0.02204404597058232, 'max_depth': 6, 'subsample': 0.8509985911445586, 'colsample_bytree': 0.8579279997894902, 'lambda': 0.007810114375702504, 'alpha': 0.003432643576612929}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:24,379] Trial 42 finished with value: 0.8880034208297729 and parameters: {'booster': 'gbtree', 'n_estimators': 387, 'learning_rate': 0.014195978071176235, 'max_depth': 6, 'subsample': 0.7520188025988802, 'colsample_bytree': 0.8085565600181523, 'lambda': 0.006030806969083058, 'alpha': 0.0014510539295863423}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:27,891] Trial 43 finished with value: 0.8883512258529663 and parameters: {'booster': 'gbtree', 'n_estimators': 456, 'learning_rate': 0.023250195696291644, 'max_depth': 4, 'subsample': 0.6627428186764778, 'colsample_bytree': 0.7471630071323191, 'lambda': 0.002055353103451517, 'alpha': 0.013030491486373173}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:34,379] Trial 44 finished with value: 0.8875054001808167 and parameters: {'booster': 'gbtree', 'n_estimators': 417, 'learning_rate': 0.040120105873903064, 'max_depth': 7, 'subsample': 0.7427716904596866, 'colsample_bytree': 0.7163930575415901, 'lambda': 0.22369665423196777, 'alpha': 0.007081094954541008}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:41,800] Trial 45 finished with value: 0.4067627310752869 and parameters: {'booster': 'gbtree', 'n_estimators': 316, 'learning_rate': 0.0010184809266170687, 'max_depth': 8, 'subsample': 0.8112661498452691, 'colsample_bytree': 0.8815089386073414, 'lambda': 0.06159187561431128, 'alpha': 0.004743213263388702}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:45,650] Trial 46 finished with value: 0.881127905845642 and parameters: {'booster': 'gbtree', 'n_estimators': 367, 'learning_rate': 0.00845612403341111, 'max_depth': 5, 'subsample': 0.6847024497353988, 'colsample_bytree': 0.8231496530797567, 'lambda': 0.005318726963313545, 'alpha': 0.16880221863669026}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:48,448] Trial 47 finished with value: 0.8839720726013184 and parameters: {'booster': 'gbtree', 'n_estimators': 431, 'learning_rate': 0.01735192288096115, 'max_depth': 3, 'subsample': 0.5819895478388192, 'colsample_bytree': 0.7596911780884498, 'lambda': 0.01425420435167862, 'alpha': 0.0023025795588077075}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:54,752] Trial 48 finished with value: 0.8860567450523377 and parameters: {'booster': 'gbtree', 'n_estimators': 499, 'learning_rate': 0.053884826351823324, 'max_depth': 6, 'subsample': 0.6157942665968715, 'colsample_bytree': 0.8459053988679494, 'lambda': 0.8919644070538263, 'alpha': 0.016757645884779113}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:07:58,740] Trial 49 finished with value: 0.887906813621521 and parameters: {'booster': 'gbtree', 'n_estimators': 246, 'learning_rate': 0.01965317638382725, 'max_depth': 7, 'subsample': 0.7181048425807982, 'colsample_bytree': 0.7925035048012786, 'lambda': 0.0018561242249217627, 'alpha': 0.009289251316394711}. Best is trial 32 with value: 0.8890104413032531.
# [I 2024-09-09 11:08:04,463] Trial 50 finished with value: 0.8891641139984131 and parameters: {'booster': 'gbtree', 'n_estimators': 458, 'learning_rate': 0.014304796242824509, 'max_depth': 6, 'subsample': 0.5305179000194723, 'colsample_bytree': 0.7340564508142687, 'lambda': 0.011885291931034938, 'alpha': 0.004142967828127302}. Best is trial 50 with value: 0.8891641139984131.
# [I 2024-09-09 11:08:10,252] Trial 51 finished with value: 0.8893107652664185 and parameters: {'booster': 'gbtree', 'n_estimators': 469, 'learning_rate': 0.014135672072196898, 'max_depth': 6, 'subsample': 0.5294820956414361, 'colsample_bytree': 0.6947908806225822, 'lambda': 0.00990259428348253, 'alpha': 0.0042688873100331865}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:08:15,072] Trial 52 finished with value: 0.8885453701019287 and parameters: {'booster': 'gbtree', 'n_estimators': 478, 'learning_rate': 0.014212366053323653, 'max_depth': 5, 'subsample': 0.5343059858311923, 'colsample_bytree': 0.6042541335310356, 'lambda': 0.010876510735177942, 'alpha': 0.004918278352079469}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:08:24,160] Trial 53 finished with value: 0.8890656352043151 and parameters: {'booster': 'gbtree', 'n_estimators': 456, 'learning_rate': 0.011411796944750655, 'max_depth': 8, 'subsample': 0.5254656220946765, 'colsample_bytree': 0.731704747616486, 'lambda': 0.03477354327050739, 'alpha': 0.002069281259360653}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:08:33,286] Trial 54 finished with value: 0.8890537738800048 and parameters: {'booster': 'gbtree', 'n_estimators': 460, 'learning_rate': 0.011197903750712482, 'max_depth': 8, 'subsample': 0.5250913056348574, 'colsample_bytree': 0.7282030834609483, 'lambda': 0.03384158320509152, 'alpha': 0.001373947296234197}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:08:42,759] Trial 55 finished with value: 0.888631808757782 and parameters: {'booster': 'gbtree', 'n_estimators': 463, 'learning_rate': 0.010592277454511656, 'max_depth': 8, 'subsample': 0.5257960170937027, 'colsample_bytree': 0.679017606697959, 'lambda': 0.036425242451327514, 'alpha': 0.0013038833345814013}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:08:55,254] Trial 56 finished with value: 0.8777941584587097 and parameters: {'booster': 'gbtree', 'n_estimators': 394, 'learning_rate': 0.006258885650424771, 'max_depth': 10, 'subsample': 0.5538655086558221, 'colsample_bytree': 0.7390535226204469, 'lambda': 0.06969864897145697, 'alpha': 0.002051420057970859}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:09:05,565] Trial 57 finished with value: 0.8876554727554321 and parameters: {'booster': 'gbtree', 'n_estimators': 440, 'learning_rate': 0.009548393840435734, 'max_depth': 9, 'subsample': 0.5159101520239497, 'colsample_bytree': 0.6314199057759848, 'lambda': 0.020432524319004546, 'alpha': 0.002310474499201986}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:09:13,140] Trial 58 finished with value: 0.8878139734268189 and parameters: {'booster': 'gbtree', 'n_estimators': 459, 'learning_rate': 0.008153105371971656, 'max_depth': 7, 'subsample': 0.5403644400845492, 'colsample_bytree': 0.727200431233118, 'lambda': 0.012115710012685412, 'alpha': 0.0012147835742548664}. Best is trial 51 with value: 0.8893107652664185.
# [I 2024-09-09 11:09:21,506] Trial 59 finished with value: 0.8670479893684387 and parameters: {'booster': 'gbtree', 'n_estimators': 408, 'learning_rate': 0.0050176074612139285, 'max_depth': 8, 'subsample': 0.5017301809706026, 'colsample_bytree': 0.6823863400703738, 'lambda': 0.029007405232926376, 'alpha': 0.00391747719787301}. Best is trial 51 with value: 0.8893107652664185.
# Best hyperparameters: {'booster': 'gbtree', 'n_estimators': 469, 'learning_rate': 0.014135672072196898, 'max_depth': 6, 'subsample': 0.5294820956414361, 'colsample_bytree': 0.6947908806225822, 'lambda': 0.00990259428348253, 'alpha': 0.0042688873100331865}

# %%
best_model = xgb.XGBRegressor(**study.best_params, random_state=42, n_jobs=-1)
best_model.fit(X_train_part, y_train_part)
# Out:
# XGBRegressor(alpha=0.0042688873100331865, base_score=None, booster='gbtree',
#              callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.6947908806225822, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              lambda=0.00990259428348253, learning_rate=0.014135672072196898,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=469, n_jobs=-1, ...)

# %%
best_model.save_model("/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/models/xgboost.json")

# %%
loaded_model = xgb.XGBRegressor(random_state=42, n_jobs=-1)
loaded_model.load_model('/Users/aswathshakthi/PycharmProjects/MLOps/Predictive_maintenance/models/xgboost.json')

# %%
# Predict on train, validation, and test sets
y_train_pred = loaded_model.predict(X_train_part)
y_valid_pred = loaded_model.predict(X_valid)
y_test_pred = loaded_model.predict(X_test_normalized)

# %%
y_train_pred = np.expm1(y_train_pred)
y_valid_pred = np.expm1(y_valid_pred)
y_test_pred = np.expm1(y_test_pred)

y_train_original = np.expm1(y_train_part)
y_valid_original = np.expm1(y_valid)
y_test_original = np.expm1(y_test_normalized)

# %% [markdown]
#  ### Evaluation

# %%
r2_train = r2_score(y_train_original, y_train_pred)
r2_valid = r2_score(y_valid_original, y_valid_pred)
r2_test = r2_score(y_test_original, y_test_pred)

print(f'R-squared - Train: {r2_train}')
print(f'R-squared - Validation: {r2_valid}')
print(f'R-squared - Test: {r2_test}')
# Out:
# R-squared - Train: 0.7571252584457397
# R-squared - Validation: 0.7244778871536255
# R-squared - Test: -3.2901721000671387

# %%
mse_train = mean_squared_error(y_train_original, y_train_pred)
mse_valid = mean_squared_error(y_valid_original, y_valid_pred)
mse_test = mean_squared_error(y_test_original, y_test_pred)

print(f'MSE - Train: {mse_train}')
print(f'MSE - Validation: {mse_valid}')
print(f'MSE - Test: {mse_test}')
# Out:
# MSE - Train: 1162.8731890861256
# MSE - Validation: 1258.80409999898
# MSE - Test: 7348.869016027605

# %% [markdown]
# ### Validation Plot

# %%
plt.figure(figsize=(15, 5))

# Convert DataFrame to NumPy array and flatten
y_train_original_flat = np.ravel(y_train_original.values)
y_train_pred_flat = np.ravel(y_train_pred)
y_valid_original_flat = np.ravel(y_valid_original.values)
y_valid_pred_flat = np.ravel(y_valid_pred)
y_test_original_flat = np.ravel(y_test_original.values)
y_test_pred_flat = np.ravel(y_test_pred)

# Plot for Train set
plt.subplot(1, 3, 1)
sns.scatterplot(x=y_train_original_flat, y=y_train_pred_flat)
plt.xlabel('Actual RUL (Train)')
plt.ylabel('Predicted RUL (Train)')
plt.title('Train Set: Actual vs Predicted')

# Plot for Validation set
plt.subplot(1, 3, 2)
sns.scatterplot(x=y_valid_original_flat, y=y_valid_pred_flat)
plt.xlabel('Actual RUL (Validation)')
plt.ylabel('Predicted RUL (Validation)')
plt.title('Validation Set: Actual vs Predicted')

# Plot for Test set
plt.subplot(1, 3, 3)
sns.scatterplot(x=y_test_original_flat, y=y_test_pred_flat)
plt.xlabel('Actual RUL (Test)')
plt.ylabel('Predicted RUL (Test)')
plt.title('Test Set: Actual vs Predicted')

plt.tight_layout()
plt.show()

# %%
sns.kdeplot(y_train_normalized, label='Train')
sns.kdeplot(y_test_normalized, label='Test')
plt.title('Distribution of Target (RUL)')
plt.legend()
plt.show()
